# %%
# 導入 模組(module) 
import requests 
# 導入 BeautifulSoup 模組(module)：解析HTML 語法工具
import bs4

# 文章連結
URL = "https://www.ptt.cc/bbs/movie/search?q=%E7%8E%A9%E5%91%BD%E9%97%9C%E9%A0%ADX"
# 設定Header與Cookie
my_headers = {'cookie': 'over18=1;'}
# 發送get 請求 到 ptt 八卦版
response = requests.get(URL, headers = my_headers)


links = []
#  把網頁程式碼(HTML) 丟入 bs4模組分析
soup = bs4.BeautifulSoup(response.text,"html.parser")

## PTT 上方4個欄位
header = soup.find_all('span','article-meta-value')
for title in soup.find_all('div', class_='title'):
    link = title.find('a')
    if link:
        href = link.get('href')
        if href:
            links.append(href)

print(links)

for link in links:
    URL = "https://www.ptt.cc" + link
    # 設定Header與Cookie
    my_headers = {'cookie': 'over18=1;'}
    # 發送get 請求 到 ptt 八卦版
    response = requests.get(URL, headers = my_headers)
    soup = bs4.BeautifulSoup(response.text,"html.parser")
    ## PTT 上方4個欄位
    header = soup.find_all('span','article-meta-value')

    # 作者
    author = header[0].text
    # 看版
    board = header[1].text
    # 標題
    title = header[2].text
    # 日期
    date = header[3].text


    ## 查找所有html 元素 抓出內容
    main_container = soup.find(id='main-container')
    # 把所有文字都抓出來
    all_text = main_container.text
    # 把整個內容切割透過 "-- " 切割成2個陣列
    pre_text = all_text.split('--')[0]
        
    # 把每段文字 根據 '\n' 切開
    texts = pre_text.split('\n')
    # 如果你爬多篇你會發現 
    contents = texts[2:]
    # 內容
    content = '\n'.join(contents)
    # 顯示
    print('作者：'+author)
    print('看板：'+board)
    print('標題：'+title)
    print('日期：'+date)
    print('內容：'+content)
# Out:
# ['/bbs/movie/M.1684937870.A.3FA.html', '/bbs/movie/M.1684934881.A.749.html', '/bbs/movie/M.1684831586.A.6CC.html', '/bbs/movie/M.1684763288.A.B7C.html', '/bbs/movie/M.1684756153.A.B69.html', '/bbs/movie/M.1684749427.A.873.html', '/bbs/movie/M.1684572521.A.3EF.html', '/bbs/movie/M.1684562800.A.C9B.html', '/bbs/movie/M.1684560006.A.B84.html', '/bbs/movie/M.1684545302.A.4C0.html', '/bbs/movie/M.1684505783.A.01C.html', '/bbs/movie/M.1684488618.A.C28.html', '/bbs/movie/M.1684482576.A.146.html', '/bbs/movie/M.1684479328.A.A7C.html', '/bbs/movie/M.1684478955.A.95A.html', '/bbs/movie/M.1684456074.A.A90.html', '/bbs/movie/M.1684424563.A.08A.html', '/bbs/movie/M.1684418614.A.6CA.html', '/bbs/movie/M.1684415258.A.C99.html', '/bbs/movie/M.1684409933.A.A9E.html']
# 作者：aensland ()
# 看板：movie
# 標題：[新聞] 傑森莫摩亞成為《玩命關頭X》最大亮點！
# 日期：Wed May 24 22:17:48 2023
# 內容：新聞網址：https://reurl.cc/GAk2OW
#
# 傑森莫摩亞成為《玩命關頭X》最大亮點！親自選擇角色裝扮並自嘲：「因為我實在沒演
# 技，只好穿得水噹噹」
# https://i.imgur.com/An6KGyH.png
#
# 史上最大飆車系列第十集《玩命關頭X》(Fast X) 終於正式上映了，儘管因偏離物理定律
# 跟常人邏輯而漸漸成為笑柄，其娛樂效果還是讓大家紛紛買票捧場。這集有很多有趣的地
# 方，例如起死復生的角色、跟莫名都被收編為大家庭的反派，不過所有故事設定都比不上
# 一個人的大放異彩——飾演反派「但丁」的傑森摩莫亞。
# https://i.imgur.com/47bttS5.jpg
#
# 《玩命關頭X》最亮眼反派——傑森摩莫亞
# 傑森摩莫亞可說被一致認同為《玩命關頭X》讓人最眼睛一亮的部分，而這是他始料未及
# 的。論明星份量而言，他不是團隊裡最有名或最大咖的，而且反派角色從來不是被著重描
# 繪的部分。不過或許他低估自己的才華了，因為但丁這次被拿來跟經典反派「小丑」做比
# 較，同樣出其不意、一臉招牌笑容與浮誇裝扮，的確成為獨樹一格的存在。
#
# 「我真的超級依賴服裝跟道具，因為我實在沒演技，只好借重他們的幫忙來穿得水噹噹。
# 我跟設計師合作挑選了許多衣服，而且特別著迷於粉色系。我想要創造出溫暖、有親和力
# 的外表，因此當你靠近但丁的時候，才發現他是一個惡魔，而我們從頭到尾都被魅惑了。
# 我的概念大概是這樣。」
#
# https://i.imgur.com/65mzqj2.jpg
#
# 摩莫亞把自己的想法解釋為因缺乏演技的補救辦法，實在是太謙虛了。事實上，他的點子
# 為但丁注入了許多生命力，包括塗指甲油的片段、綁兩撮啾啾頭跟駕著薰衣草色的跑車，
# 都是他一手打造的，甚至還要為此與製作團隊據理力爭一番：
#
# 「他們原本不想給我一台薰衣草色的跑車，我想製作人尼爾的反應是『沒可能，我們不會
# 選擇薰衣草』，但我真的十分堅持，他們才妥協的。那麼想要薰衣草色的原因是，那是我
# 媽最鄙視的顏色，但剛好我又很喜歡，所以我就想要藉此來得罪她，可以一起大笑一場。
# 我把車子稱為『雅雅薰衣草』，然後決定把指甲都塗成那個色系。我真的很期待我媽看到
# 我穿得整身粉粉紫紫的，她會崩潰死，就讓我覺得好開心。」
#
#
# 摩莫亞的天馬行空 造就經典場景
# 雖然這原因聽起來不太對勁，但是摩莫亞能夠發揮本色，結合自身的特質跟魅力，就是塑
# 造但丁最成功的關鍵。除了衣著以外，但丁跟唐老大的近距離肉搏原本設計為不相上下的
# 拉鋸戰，是摩莫亞認為情況可以稍微調整，更接近但丁嬉鬧的性格：
#
# 「我覺得看到但丁被唐老大打爆很有趣，因為這是但丁想要的。表面上佔了下風，但他才
# 能更接近唐老大，讓唐老大有一點掉以輕心。」
#
# https://i.imgur.com/85UtAXG.jpg
#
# 同時身為水行俠的摩莫亞當然不害怕打架，即使牙齒掉了也在所不惜。而且他還想把這場
# 架搞得更瘋狂，差點讓劇組招架不住：
#
# 「我當時掉了一顆臼齒。我怕死牙醫了，從來都沒拔過臼齒，結果就這樣裂開了。因此我
# 決定那是一個關鍵性的時刻，既然我那裡有一個缺口，就覺得『你把我牙齒打碎了，那我
# 就把剩下的拔出來丟回去，看還要丟屎還是什麼的也可以。』」
#
# 在場人員實在是嚇瘋了，趕緊阻止他再天馬行空下去。不過腦洞一開豈是能馬上就停下來
# 的，於是只好兩手一攤讓他自由發揮，就繼續讓他兩肖維，造就了接下來也很經典的畫面
# ：
#
# 「我們在胡扯一番之後，我就突然問馮『你喜歡芭蕾嗎？』，他還想說什麼東西，結果我
# 就現場亂跳《天鵝湖》起來。他們還真的願意讓我這樣做，我趕緊 Google 要怎麼跳，現
# 學現賣。我不知道他們還有沒有保留這段，但在場有特技演員跟一堆非常成年的男子，大
# 家就這樣一起看我跳芭蕾舞，這個場景就這樣突然誕生了。」
#
# 身高193公分的大隻佬摩莫亞突然開心地在現場手舞足蹈，相信看過《玩命關頭X》的觀眾
# ，也會認同這是一個有趣爆笑的神來一筆，十分符合但丁瘋癲的性格。
#
# 誰能料到呢，或許玩命關頭真的會成為 DC超級英雄的第二春，讓所有在隔壁還沒得到適
# 當舞台的演員，能夠在這裡好好發揮本色，成為演藝生涯的另一大里程碑。
#
#
# 作者：zacksnyzhi (查克史奈智)
# 看板：movie
# 標題：[普無雷] 玩命關頭X 就那樣吧…
# 日期：Wed May 24 21:27:56 2023
# 內容：
# 《玩命關頭X》就那樣吧… 6/10分
#
# 本系列拍到第十集
# 也是最終三部曲的第一部
# 感覺得出來有意將全部系列出現過的人都集結起來
# 該片的導演本來是拍過本系列34569集的林詣彬
# 後來因創作分期改為拍過《鬥犬》《玩命快遞2》《無敵浩克》《超世紀封神榜》《出神
# 入化》的路易斯‧賴托瑞
# 拍過的片也算是不錯的商業片啦
# 所以《玩命關頭X》整體也算娛樂性十足
#
# 主要特別讚賞在許多飆車運鏡
# 都有給到該有的爽感
# 無論是飛車追逐、尬車比賽、障礙賽(?
# 都有以前的熱血感
# 搭配穿梭機的快速逼近拉遠
# 也增加了許多場面的震撼度
#
# 劇情部分
# 就還是家庭、家人那套
# 但由馮迪索這位面癱肌肉演員來演
# 就沒什麼特別感覺 就不是特別在乎
#
# 而原本以為由傑森‧摩莫亞a.k.a水行俠飾演的反派
# 一樣是刻板的無腦大老粗
# 沒想到還滿有特色的
# 有點像黑暗騎士的小丑帶點三八感?
# 也成為片中的一大亮點
#
# 總結
# 飆車場面可看
# 反派有趣
# 其他演員跟劇情無所謂啦
# 就跟之前差不多
#
# 喜歡再進場就好
# 不看其實也沒差
#
#
#
# 作者：nyk3 (阿晃)
# 看板：movie
# 標題：[新聞] 《玩命關頭X》才上映！莉蒂再曝第11集
# 日期：Tue May 23 16:46:24 2023
# 內容：新聞網址：https://www.nownews.com/news/6146950
#
# 《玩命關頭X》才上映！莉蒂再曝第11集「飆速進度」：導演好興奮
#
# 記者黃雅琪/綜合報導
#
# 2023-05-22 14:08:14
#
# 好萊塢經典動作鉅片《玩命關頭》續集電影《玩命關頭X》，上週上映立刻引起轟動，北
# 美首週末3天票房來到6750萬美元（約台幣2.06億元），全球票房更達到3.19億美元（約
# 台幣97.66億元）。飾演莉蒂歐提茲的女星蜜雪兒羅德里奎茲受訪時透露，《玩命關頭11
# 》製作上的「最新進度」，更預告第12集也即將登場。
#
# 《玩命關頭X》導演路易斯賴托瑞與主要演員馮迪索、蜜雪兒羅德里奎茲、喬丹娜布魯斯
# 特、艾倫瑞奇森和姜成鎬，一起參加由莎莉賽隆成立的CTAOP慈善組織所舉辦的年度募款
# 活動，主角莎莉賽隆因為確診新冠肺炎無法出席，但她仍錄製影片致謝《玩命關頭》的家
# 人們，還開玩笑說：「盡力出資，否則我會來找你！」
#
# 蜜雪兒羅德里奎茲接受外媒採訪時也透露，《玩命關頭X》續集《玩命關頭11》已經拍攝
# 完畢，目前正在製作中，全片進入到後製剪片階段，所有的想法都在飛快進行中！她補充
# 提及，《玩命關頭X》導演路易斯賴托瑞為此忙得不可開交，但他興奮得像個小孩一樣。
# 《玩命關頭X》現正熱映中。
#
#
# 作者：mumma (瑪)
# 看板：movie
# 標題：[雷] 負雷 玩命關頭X
# 日期：Mon May 22 21:48:06 2023
# 內容：
# 沒有難看，只有超級難看
#
# 全場還稱得上有演技的大概就莎莉賽隆、傑森史塔克和傑森摩莫亞
#
# 可能因為和光頭馮演戲的關係
#
# 不知道是為了配合他的演技自動把等級降低，還是近墨者黑
#
# 真的非常難看
#
#
#
#
#
# 作者：LPbro (LP哥)
# 看板：movie
# 標題：[新聞] 《玩命關頭X》全台5天飆1.3億！猛破今年
# 日期：Mon May 22 19:49:11 2023
# 內容：新聞網址：
#
# 《玩命關頭X》全台5天飆1.3億！猛破今年首週開片及單日票房成績
#
# 2023/05/22 17:51
#
# https://img.ltn.com.tw/Upload/ent/page/800/2023/05/22/4309652_1.jpg
# 《玩命關頭X》全台5天飆出1.3票房佳績，登上全台票房冠軍。（UIP提供）
#
# 〔記者許世穎／台北報導〕賣座電影《玩命關頭》系列第10集《玩命關頭X》，上週三（
# 17日）搶先美國在台上映，全台首週票房正式出爐！5天開出台幣1.3億元的票房佳績，不
# 僅刷新今年首週開片票房紀錄，也打破今年最高單日成績。
#
# 除了空降全台冠軍，該片同時也拿下上週全美以及全球票房冠軍，北美首週末3天粗估票
# 房為6750萬美金（約台幣2.06億元），全球票房更高達3.19億美金（約台幣97.66億元）
# 。《玩命關頭X》全台持續上映中。
#
# https://ent.ltn.com.tw/news/breakingnews/4309652
#
#
#
# 作者：ghostl40809 (gracias)
# 看板：movie
# 標題：[好雷] 玩命關頭X 好雷是因為水行俠
# 日期：Mon May 22 17:57:02 2023
# 內容：無視時差的瞬間移動
#
# 或是那顆滾到比捍衛任務裡基哥某段還尬的炸彈
#
# Family? 有人真的在算講了幾次嗎?
#
# 便當吃了又吐 眼淚變得廉價
#
# 至少
#
# 這騷底又雞巴的反派
#
# 名字還叫但丁
#
# 是要用他的神曲帶大家經歷玩命關頭這X地獄吧
#
# 瞎趴的西裝
#
# 可愛的髮型
#
# 幫屍體擦指甲油
#
# 或是學變臉舔正妹臉頰?
#
# 髮型下次來個雙馬尾吧
#
# https://imgur.com/uYllVQ7
#
#
# 作者：likeaprayer (Dreamlover)
# 看板：movie
# 標題：[討論] 玩命關頭X 北美觀眾出口民調B+ 持平9
# 日期：Sat May 20 16:48:39 2023
# 內容：
#
#
# 北美觀眾出口民調調查官方網站:
#
# https://www.cinemascore.com/
#
#
# 玩命關頭全系列出口民調評分:
#
#  B+ 玩命關頭 2001/06/22
#  A- 玩命關頭2：飆風再起 2003/06/06
#  A- 玩命關頭3：東京甩尾 2006/06/16
#  A- 玩命關頭4 2009/04/03
#  A  玩命關頭5 2011/04/29
#  A  玩命關頭6 2013/05/24
#  A  玩命關頭7 2015/04/03
#  A  玩命關頭8 2017/04/14
#  B+ 玩命關頭9 2021/06/25
#  B+ 玩命關頭X 2023/05/19
#
#  A- 玩命關頭：特別行動 2019/08/02
#
# 這系列評價形成一個滿有趣的趨勢，從第1~5集是逐步上升，
#
# 第5~8集維持巔峰，外傳開始下跌。
#
#
# 目前北美票房表現是提早場750萬美元，首日2750萬美元(含週四提早場)，
#
# Deadline認為這部在週末會取得6600萬美元的成績，
#
# 這個開盤略低於2021年疫情期間上映的玩命9約8%。
#
# 本作海外票房將會是最關鍵的回本主場。
#
#
#
# 作者：bpf1980 (半瓶醋)
# 看板：movie
# 標題：[好雷]烤肉與尬車的飆車邪教！
# 日期：Sat May 20 14:06:37 2023
# 內容：雷文防雷資訊頁
#
#
#
# ~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~*-*~
#
#
#
# ~~~~~~~~~~~~~~~~~~~ 雷文 主文分隔線 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# https://youtu.be/1d1f1WCfuVY
#
# 在上一集唐老大與弟弟雅各的事件過後，唐老大一家過著幸福快樂的日子，他開始教剛長
# 大的孩子甩尾，而他的好麻吉布萊恩也疑似終於過世(?，唐老大經常看著他的照片思念他。
#
# 然而好景不常，幾年前被唐老大整死的巴西黑幫老大赫曼雷耶斯之子但丁雷耶斯堂堂現身
# ，他不但擊敗了唐老大的宿敵賽芙，霸佔了她的人馬與技術，而且還打算要狠狠的折磨唐
# 老大，使他生不如死。
#
# 唐老大的夥伴因此一個個遭逢災禍，究竟唐老大一夥人與但丁的對決會有什麼結果呢？
#
# 我得承認，雖然我熱愛動作片電影，但是我就是對【玩命關頭】系列很冷感，這個由羅伯
# 柯恩在2001年所開創的系列電影，一開始只是臥底警察與街頭混混間的情誼故事，經歷歷
# 次的演員更迭，前期一路顛簸的搞到第三集，讓接手的新銳導演林詣彬拍出【東京甩尾】
# 敗部復活，才開創了第二春，直到第五集【玩命關頭5】，全系列的劇情與場面達到了巔
# 峰。
#
# 我是到那個時期才開始對【玩命關頭】系列感興趣的。
#
# 而在這個系列拍到第九集，讓趙喜納變成唐老大的弟弟，各種超現實的飆車場面充斥，還
# 讓成員們上太空的超莫名故事出現之後，我幾乎已經對這個系列見怪不怪了。
#
# https://youtu.be/T_C2ZNsWe5I
#
# 但是他就是有一種魔性，就算我沒有特別的期待，當光頭們第十次玩命的時候，我還是忍
# 不住要去看他們這一次要搞什麼。
#
# 其實我發現，【玩命關頭X】的製作團隊其實也滿清楚自己的弱點與優點的，就像我前面
# 提到的，我個人一直都覺得這個系列最精彩的動作場面是在【玩命關頭5】，看樣子他們
# 也這麼認為，所以【玩命關頭X】全片是拼了命地在把觀眾對於【玩命關頭5】的情懷拉回
# 來，不但英文片名沿襲了【玩命關頭5】的「Fast 5」，叫做「Fast X」，故事也是從五
# 代的大鬧里約事件去補設定，原來當年巴西的黑幫老大還有個猛男兒子但丁(傑森摩墨亞)
# ，然後這對父子感情甚佳，但是卻有非常扭曲的道德觀，結果在唐老大拖金庫的事件讓但
# 丁痛失老爸，怒火中燒的他決定要報仇，而且非但要讓唐老大死，而且還要折磨到他生不
# 如死。
#
# 作為反派的傑森莫摩亞的演員魅力相當大，在【玩命關頭8】的巨石強森跳舞之後，傑森
# 莫摩亞再一次證明，一個男子氣概爆棚的人是根本不用怕做娘炮行為的，所以但丁這個角
# 色不但穿上紫色的絲質外衣，頭髮綁上五顏六色的髮辮，然後還有一場戲要邊塗指甲油邊
# 跟屍體們碎嘴。
#
# 這些行為可全都是自詡為「真男人」偶包的馮迪索從未做過的事啊，我邊看都不由得覺得
# 編導根本是故意讓但丁這個角色跟唐老大做出極端的差異。我有的時候都覺得他的那些行
# 為蠻可愛的，即使他在裡頭好像一直在做壞人的事情，但是就是很難讓人討厭他。
#
# 除了故事緊貼著五代發展之外，這一集甚至連動作場面的理念都是遵循著五代傳下來的概
# 念，重點已不是飆車的速度，而是完完全全的「破壞」，因此在開場不久，唐老大的好友
# 們前往羅馬執行任務卻中了但丁的圈套的動作戲，就是十足的搞破壞場面，唐老大與他的
# 家人們拼命地想要阻止一顆埋了炸彈的鐵球爆炸，然後這顆鐵球滾遍羅馬各地景點，最後
# 華麗的震撼爆破，讓觀眾們吃下一記豪華的物理災難場面。
#
# 這場特效戲可說是整部電影最精彩的動作場面了，然後接下來的精彩度就一路往下滑，因
# 為但丁這個角色就沒有要急著殺唐老大，他還要折磨他呢，怎麼可以很快殺死他呢？然後
# 情治單位又因為羅馬的事件開始追捕唐老大一行人。
#
# 艾姆斯探員：唐多米尼克這一黨全都是危險人物與破壞份子！他們靠著搶劫與偷竊起家，
# 他們違反上帝規則和物理定律，最擅長的就是吸收拉攏本來要抓捕他們的情治單位人員，
# 靠著烤肉與飆車這種行為讓自己脫罪洗白，簡直就是一個飆車邪教！"
#
# 此時螢幕上顯示的顯示的「情治人員」分別是布萊恩奧康納（保羅沃克）、盧克霍布斯（
# 巨石強森）與無名氏先生（寇特羅素）
#
# 這簡直是整部電影最佳金句，一講出口，當場讓布莉拉森無言以對。
#
#
# 故事繼續走下去，唐老大一家又變成了逃犯，大家四散潛伏逃命，這使得整部電影的後半
# 截變得相當鬆散，基本上就是四散的夥伴們邊躲避抓捕邊吵架的日常，中間還補充了不少
# 設定，唐老大跑去找蕭媽媽聊一聊又跟但丁在里約尬車，然後還順便保護了一下他前女友
# 的妹妹，韓哥跟兩位黑人夥伴一行則是跑去找戴克蕭，結果莫名打了一架之後就沒有然後
# 了，唐太太利蒂則是跟賽芙這個前仇人在監獄裡頭打了一架之後不得不跟他一起逃獄，我
# 還記得幾年前我在【玩命關頭8】的評論是這樣講的：
#
# https://youtu.be/02oFuIA52Aw
#
# ”昨天的敵人今天就可以變朋友，一切只是因為看對了眼或是發現對方其實跟自己有個相
# 同點，要當光頭們的家人很簡單的啦，只要你讓他心情好，管你之前跟他再怎麼糟糕，都
# 可以一笑泯恩仇。
#
# 所以囉，這個系列不會有任何真正的敵人，他們永遠都不會讓反派掛掉的，好不容易請來
# 莎莉賽隆來演反派誒，接下來可能就又要看莎莉賽隆變成光頭們的朋友了。”
#
# 看吧，我簡直神預言。
#
#
# 比較有趣的一條支線是趙喜納與唐的兒子忙命天涯的支線，不是我在說，趙喜娜真是孩子
# 們的好夥伴啊，絕對是個酷叔叔！他跟巨石強森不愧都是WWE出來的，看起來就像個活生
# 生的卡通人物，比馮迪索還適合跟孩子們玩在一起。
#
#
#
# 而且中文字幕把他的台詞翻譯的中二感超重的：
#
# "兄弟啊！是時候讓我活出自己的精彩啦！"
#
# 電影演了兩個小時，在一群人插科打諢，又順便打架提振觀眾精神之後，最後唐老大終於
# 要跟小朋友會合，但丁也搶到了可以找到唐的小孩的裝置「天眼」，哎啊，這玩意之前在
# 七代出現過，想必觀眾還記得吧。
#
# 於是最後就在水庫，但丁與唐老大展開了決戰，唐老大飆出名台詞：
#
# 「你最大的錯誤就是沒有搶走我的車」
#
# 接著又是一場讓觀眾回憶五代金庫場面的動作戲，他開著車子拖行兩架直升機，並且不斷
# 打轉破壞環境，然後又在爆炸當中帶著自己的孩子飆下水庫的水道。
#
# 然而，唐老大的危機沒有解除，但丁的下一波攻擊又將來到。
#
# 然後咧？沒有然後了，我們要看下一集了。
#
# 總體而言，【玩命關頭X】是一部娛樂爆米花片的極致，他的故事簡單明瞭，而且因為就
# 沒有打算把故事說完，所以電影就致力於不斷的描繪角色們的個性，所以電影的步調挺舒
# 緩的，並不緊湊。這又是一場轟炸娛樂嘉年華，但他們這一次比較有誠意，所以在娛樂性
# 與角色魅力的演繹比前兩集的效果都還好，而故事沒完結，之後還會變成三部曲，所以觀
# 眾們又有得等了。它就是潮片當中的潮片，足以讓平常非影迷的一般潮人們願意湊熱鬧進
# 場，而且看完之後還會心滿意足的留念並且覺得好好看喔。有什麼能比猛男開車把環境搞
# 得一團糟更令人覺得熱鬧的場面呢？
#
# 這部電影有一個隱藏片尾，兩個角色又再度回歸了，這個回歸都讓我覺得之前幾年【玩命
# 關頭】傳出演員們在社群的上的不和與恩怨，應該都跟ＷＷＥ的模式一樣，都是炒作的，
# 畢竟沒有前面幾年沸沸揚揚的新聞，這個回歸哪還有什麼重量呢？
#
# 而另一個角色的回歸，我其實也不能算是很意外了，畢竟【玩命關頭】系列的角色起死回
# 生的案例也已經不是第一次了，但我只能說這個演員今年度實在串場天王，我已經是第Ｎ
# 次看到他了，結果每次都只有幾秒而已，而且每次出場都還是高潮點，堪稱是以秒計費的
# 年度演員啊！
#
#
#
# 作者：barttien (田園城市(BART))
# 看板：movie
# 標題：[請益] 玩命關頭X 值得看3D版本嗎？
# 日期：Sat May 20 13:20:03 2023
# 內容：感覺板上完全沒有人提3D版本的體驗，
# 是不是現在的3D版本就像板友推文說的，
# 只是拿來騙錢的方式？
# 被看破手腳了所以大部分的人還是選擇IMax就好？
# 玩命關頭X的3D效果應該也是後製加上的而已吧？
# 有沒有看過3D版本的板友分享一下心得？
#
# 謝謝。
# 作者：nyk3 (阿晃)
# 看板：movie
# 標題：[請益] 玩命關頭X的兩個疑問(有雷)
# 日期：Sat May 20 09:15:00 2023
# 內容：第一
# 傑森·史塔森飾演的戴克·蕭
# 在遇到韓哥等人之前
# 把某人當成沙袋揍
# 後來袋子破了,人掉下來
# 體型肥胖,貌似休·葛蘭
# 但不確定是不是
# 請問有人知道他揍的是誰嗎？
# (雖然蕭一直在揍人...)
# ->更新
# 感謝N大
# 原來第九集的片尾彩蛋就有一樣的場景了
# 查網路資料,被揍的是是蕭抓到的俄羅斯罪犯
#
# 第二
# 莎莉·賽隆飾演的的賽芙
# 跟蜜雪兒·羅德里奎茲飾演的莉蒂·歐提茲
# 穿好冬衣準備要逃上去之前
# 賽芙說了一句
# 謝謝你,賽芙琳(不知有無記錯名字)
# 那請問有人知道她說的是誰嗎
# 謝謝自己???
#
# 以上
# 感謝回答
#
#
# 作者：joeblack0212 (沒投資的命拉)
# 看板：movie
# 標題：[好無雷] 玩命關頭X，第五集之後最佳
# 日期：Fri May 19 22:16:21 2023
# 內容：
# 其實我對於街頭混混變成特務並沒有太大的意見，
# 動作片，看得爽才重要。
#
# 但實在是被前兩集嚇到了，有夠難看…
# 加上對於肥牡蠣話題實在是覺得有夠膩，
# 本來想等多一點評論再去看，
# 但剛好今天有空，
# 所以衝著上面幾篇好雷，就再給肥牡蠣一個機會
#
# 結論是：
# 1.整體有回到之前的水準，節奏緊湊，給推
# 2.光頭可不可以不要這麼愛耍帥，憂鬱皺眉裝中二的鏡頭再少一點，會舒服一點
# 3.水行俠的演出是個亮點，有夠瘋
#
# 作者：xyyzzz (ZZZ\)
# 看板：movie
# 標題：[好雷]值得進戲院看的玩命關頭X
# 日期：Fri May 19 17:30:16 2023
# 內容：
#
#
#   玩命關頭x,aka 肥牡蠣無限之戰 aka 路上碰到賣不好DC英雄
#   基本上就是1-9集之大成 開場倒敘就讓人驚艷..
#   你想到的動作場面 經典場景  人物 這部都有 除了回不去的
#
#
#   進場前請理組 拋棄一切物理定律跟科學知識
#         請文組 拋棄邏輯概念跟情感
#         連編劇都吐槽這根本是肥牡蠣邪教..
#         這部會看得挺爽 應該是第5集後最佳的一部..
#         基本上沒啥劇情就是平鋪直述演過去..
#         超跑+辣妹+下重本的後製CG 難怪說很燒錢
#         整場動作場面特效比復仇者聯盟這種綠幕電影還用心
#         不會有假假的感覺
#
#         坦白說 如果不要消費保羅會更好
#         知名演員都已經很多了 真的不用再刻意提起保羅
#         除非你要讓她女兒出演下部電影
#
#
#   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#    雨           雨          雨
#    田           田          田
#
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
#
#
#
#   基本上彩蛋就不到20秒的Gal跟 巨石
#   我猜應該是下一步主角 是說巨石不是說拒絕合作了
#   而且這部演員一堆 片酬就算很香應該也拿不多吧
#
#   美女擔當蜜雅劣化的很嚴重 尤其是臉部特寫拉近的時候
#   是說查維基才發現她只演玩命關頭系列耶 就賣臉而已片酬是有那麼高能嗎
#
#   本片正翻的驚奇隊長  戲份不算少但是腳色挺醬油
#   不曉得是不是有減重
#   國字臉變得不明顯 穿搭也很好看
#
#
#   伊蓮娜的妹妹:很眼熟但是就想不起來是誰 原來是自殺突擊隊的老鼠女..
#   最好看的配角 身材又好
#   本來想說會更巴西火辣風格一點直接穿內衣外搭還是有比基尼鏡頭
#
#
#   男主角肥牡蠣抬頭紋跟魚尾紋老化的超嚴重 一度以為這部主角是布魯斯威利(O)
#   莎莉賽隆的賽芙跟莉蒂就老樣子維持水準
#   但是戲份比驚奇隊長還少
#
#
#   公認演的最好的是水行俠 感覺開創自己另一條戲路
#   你說致敬小丑 其實就沾個皮毛而已
#   反派(X)  精神病患者(O)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 作者：godofsex (性愛戰神)
# 看板：movie
# 標題：[新聞] 《玩命關頭X》要賣到8.5億美金才能打平
# 日期：Fri May 19 15:49:33 2023
# 內容：系列最昂貴！
# 《玩命關頭X》要賣到8.5億美金才能打平
#
# 2023年5月18日 週四 下午6:44
#
# https://i.imgur.com/3pPXVZp.jpg
#
# 《玩命關頭X》（圖：Universal）
#
# 【文／血紅蘭姆】
#
# 在製作成本創下系列電影新高之後，《玩命關頭X》則必須仰賴海外票房挹注，才有辦法
# 收支打平。
#
# 在跟馮迪索撕破臉、還另拍外傳電影《玩命關頭：特別行動》之後，《玩命關頭X》此番
# 好不容易請到巨石強森回鍋客串。雖然原本宣佈第十一集就要劃下句點，馮迪索日前卻大
# 喊要加拍第十二集，媒體也證實巨石強森會在續集中正式登場亮相，看來片商似乎對《玩
# 命關頭X》顯得信心滿滿。
#
# 不過《玩命關頭X》在製作過程中可也一波三折，首任導演林詣彬以往曾操刀過五集《玩
# 命關頭》系列電影，沒想到他竟在電影開鏡一週後臨時掛冠求去，片商只好緊急請到《出
# 神入化》導演路易斯賴托瑞代打上陣，也為這部新片增添了不少變數。
#
# https://i.imgur.com/dTmCeGa.jpg
#
# 《玩命關頭X》（圖：Universal）
#
# 根據The Wrap報導，除了因為更換導演而導致劇組停工之外，還得考慮到防疫安全措施、
# 全球物價狂飆，本片更在羅馬、里斯本實地取景，也讓《玩命關頭X》的製作成本一路漲
# 到了三億四千萬美金，遠比上一集《玩命關頭9》兩億至兩億兩千五百萬美金的製作成本
# 高上許多。
#
# 在此同時，《玩命關頭》系列電影的卡司陣容也跟著不斷膨脹，非但傑森史塔森、莎莉賽
# 隆、約翰希南等過去的反派角色如今都搖身一變為正式班底，這次又新加進了傑森摩莫亞
# 和布麗拉森，也讓本片的演員片酬變得越來越可觀。
#
# 如果能像《玩命關頭7》、《玩命關頭8》一樣雙雙衝破十億美金大關的話，倒還不必擔心
# ，不過上一集《玩命關頭9》卻只攻下了七億兩千六百萬美金，雖然本片是在疫情期間上
# 映，但還是為《玩命關頭X》留下了些許隱憂。
#
# 根據The Wrap估計，《玩命關頭X》至少要賣到八億美金、甚至是八億五千萬美金，本片
# 才有辦法打平。
#
# 考慮到本系列電影一向在海外市場比較受歡迎，對北美觀眾來說則沒那麼吃香，本片的成
# 敗關鍵就得視海外票房表現、尤其是中國大陸市場而定了。
#
# 《玩命關頭X》現正在台熱映中。
#
# 新聞網址：
#
# https://ynews.page.link/YRHkR
#
#
# 作者：playful0430 (喬幫主)
# 看板：movie
# 標題：[討論] 玩命關頭X（有雷）
# 日期：Fri May 19 14:55:26 2023
# 內容：防雷
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
#
# 物理方面不合理都已經自嘲了
# 就不針對這塊
# 不知道印象有沒有錯
# 一開始的羅馬球球炸彈
# 雖然說已經把它撞到河裡了
# 但是那個爆炸威力還是很驚人
# 不可思議的是
# 後來新聞報導說「無人死亡」？
# 有點離譜吧
# 但丁從賽芙那抓來的兩個臨時工
# 後來畸形成那樣
# 應該是爆炸後造成的
# 追唐的車隊也全都飛出去
# 怎麼可能都沒事
# 還有爆炸的半徑一堆平民
# 有可能無人死亡？
# 還是我記錯？
#
#
# 作者：warlockeric (黑色肥貓)
# 看板：movie
# 標題：[好雷] 玩命關頭X:伐木力前傳
# 日期：Fri May 19 14:49:13 2023
# 內容：
# 雖然之前一直嘴系列的前幾集
#
# 畢竟是青春所以還是來支持一下
#
# 年少輕狂的回憶
#
# 總是要有個結尾才算有始有終
#
# 結果意外的好看
#
# 熟悉的熱血跟狗血都回來了
#
# 因為是動作爽片所以我通常不會太苛求劇情
#
# 這部劇情也還行雖然反派有點硬要的感覺
#
# 但反正反派為什麼是反派在這部也不重要
#
# 主要是看妹子飆車搞笑跟爆炸
#
# 從這四個面向來說他們做的很好
#
# 米雅跟莉蒂一樣的好看
#
# 從以前的拉丁辣妹到現在的MILF
#
# 果然Latina就是最頂的
#
# 特別是剛開頭還在溫馨family的時候
#
# 看莉蒂一個跳到唐身上當無尾熊
#
# 那個鏡頭那個熟悉的move
#
# 讓我都開始懷念之前的拉丁前任
#
# 前半段的飆車戲也是好看
#
# 沒有再什麼亂七八糟的飛上太空
#
# 就是認真的加速衝撞甩尾跟爆炸
#
# 還有經典的摩托車領航+秀特技
#
# 真的只能說不愧是最後一集
#
# 該拍的都有拍出來
#
# 最後還是要吐槽一下：
#
# 1. 反派的來由真的有點硬要而且人設也是一個psycho 臭甲樣沒有前幾集那種硬派硬漢反派帥
#
# 2. 一開始他們跟韓在玩交友軟體
# 我只能說導演不懂我們亞洲人啊
# Come on韓，we korean don’t use dating app, we go to BTS’s concert for date and fuck.
#
# 3. 然後唐老大的小孩….只能說想要日子過得去，頭上多少要帶點綠
#
# 4.最後的吐槽就是啊怎麼又復活
# 雖然有蓋爾嘉朵我真的看很爽
# 但復活就是狗血
# 不過沒事，這種狗血我買單
#
# 總體應該有個8.5/10滿推薦的
#
# 整體偏老梗但拍的好
#
# 就跟五星級飯店的蛋炒飯一樣
#
# 簡單且老樣但就是好吃
#
# 為了看這部還惹我家妹仔生氣= =
#
# 不多說了看完米雅跟莉蒂
#
# 我要去脫衣舞俱樂部摸拉丁奶了
#
#
#
#
# 作者：s654927 (至尊鏟屎官)
# 看板：movie
# 標題：[好雷]《玩命關頭X》系列水準回歸
# 日期：Fri May 19 08:27:52 2023
# 內容：防雷頁：
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 經歷了系列作4-7的高峰後，又接連慘遭8、9及外傳等三部作品的摧殘，原本已經對《玩命
# 關頭X》不抱一絲期待；甚至我單純只是因為找不到《星際異攻隊3》時間正好的場次，才
# 退而求其次地看了《玩命關頭X》。
#
# 但《玩命關頭X》卻讓我感受到系列作久違的刺激跟熱血，當然倒也不是說本集堪稱神作的
# 那種好看，而是回到系列高峰期的水準。
#
# 觀賞電影的當下，我總覺得好像在看玩命宇宙的《復仇者聯盟：終局之戰》，因為本集可
# 以說是系列名場面的總複習。
#
# 例如《玩4》的礦坑、《玩8》的殭屍車、《玩6》的雙條高速公路、《玩7》的汽車空降，
# 或是《玩5》馮迪索跟巨石強森兩群人馬相互對峙，你都能在《玩命關頭X》裡找到致敬前
# 作的場面。
#
# 甚至大家津津樂道的《玩5》拖金庫，本集中也不乏類似的元素。
#
# 只要看過的系列作越多、有印象的場面越深刻，觀賞時就會不自覺地浮現各種既視感，同
# 時喚醒觀賞前幾作時的記憶，所以我才說像極了《終局之戰》。
#
# 如果是系列作4-7的粉絲，可以放心買票進場了。本集真心不會讓人失望。
#
# 但就算完全沒看過前作，單純作為一部爆米花爽片，本片也是絕對夠格的，只是感動就會
# 少了那麼一些些就是了。
#
#
# 作者：yitingted (iloverv)
# 看板：movie
# 標題：[雷] 玩命關頭X - 意外的好看？！
# 日期：Thu May 18 23:42:41 2023
# 內容：沒想到竟然有一天我會期待下一集的玩命關頭...我先自首我一到九集+外傳都有看過，五到
# 七算是這系列的巔峰時期，之後的第八集、第九集都是狗屎，這集算有恢復水準，蠻適合放
# 假進電影院放鬆看。
#
# 我覺得這集比起前兩集的優點就是，他們不裝了，承認自己被吐槽的點。前兩集還在那矜持
# ，這集直接不演(上集有小吐槽子彈都打不到)，大方吐槽自己這系列就是違背物理原則、只
# 要烤肉就可以變成家人，聽到這台詞真的笑出來。確實，看這系列的觀眾誰是來看劇情的，
# 都是來看動作戲跟大場面的吧。
#
# 包含以前的角色，出場人物很多，如果沒看前面幾集會不知道這些角色是幹嘛的，不知道他
# 們的親屬關係，那可不行(畢竟family是最重要的)。這集又多了更多角色，角色都不會退場
# ，卡司真的龐大。劇情緊湊，從頭到尾幾乎沒有喘息的時間，看完覺得筋疲力盡。Jason Mo
# moa的反派不錯，蠻瘋的，也惹毛玩命宇宙中的眾多勢力。
#
# (以下有雷)
# 這集結局目前還蠻慘的，有《復仇者聯盟3》的感覺(雖然我們都知道他們不會有事就是了)
# ，要等到第十一甚至第十二集才知道接下來會發生什麼事情，Jason Momoa也還沒有真的下
# 來打。題外話，加上片尾復活的Gal Gadot以及回歸的The Rock，這系列也太多漫威DC的演
# 員了吧，首先漫威的Vin Diesel的Groot、Brie Larson的Captain Marvel、Charlize Thero
# n(超正)的Clea。DC這邊更多，回歸的Gal Gadot(超正)的Wonder Woman、The Rock的Black
# Adam、Jason Momoa的Aquaman、John Cena的Peace Maker、Daniela Melchior(超正)的RatC
# atcher 2、Helen Mirren的Hespera，下一集直接開車衝進DC多重宇宙也不意外。
#
#
# 作者：hvariables (Speculative Male)
# 看板：movie
# 標題：[新聞] 《玩命關頭X》空降全台冠軍！首日票房勇破1853萬
# 日期：Thu May 18 22:03:31 2023
# 內容：https://ent.ltn.com.tw/news/breakingnews/4306073
#
# 《玩命關頭X》空降全台冠軍！首日票房勇破1853萬
#
# 2023/05/18 19:21
#
# https://img.ltn.com.tw/Upload/ent/page/800/2023/05/18/4306073_1.jpg
# 《玩命關頭X》昨在台上映登上全台冠軍。（UIP提供）
#
# 〔記者許世穎／台北報導〕賣座電影《玩命關頭》系列第10集《玩命關頭X》，昨搶先全
# 美在台上映，這個在全球影史最具話題性、最受歡迎的飆速系列至今已邁入第23年，在台
# 依舊不墜，首日便以突破1853萬的票房佳績空降全台冠軍，票房依舊強勁。
#
# 雖然電影已邁入最終章，但核心演員與角色卻仍然和一開始一樣火力全開。導演路易斯賴
# 托瑞表示，《玩命關頭》系列即將迎向終點，所以本片也要回到最初的開始街頭「尬車」
# ，「這是一部場面浩大的娛樂大片，並匯集了觀眾熱愛玩命關頭宇宙的一切」。
#
# 男主角兼製片「唐老大」馮迪索日前出席羅馬首映會時也透露，當初思考拍攝最終章，發
# 行該片的環球影業曾問能不能分成2部，隨後又表示：「當他們看完這個上半部之後，又
# 問能不能將最終章拍成3部曲？」蜜雪兒則接著說：「任何故事都應該有3幕的形式！」換
# 言之有可能一路拍到第12集。《玩命關頭X》全台持續上映中。
#
#
# 作者：oneyoung1121 (oneyoung1121)
# 看板：movie
# 標題：[  普雷] 玩命關頭X  物理老師在哭泣
# 日期：Thu May 18 21:07:36 2023
# 內容：防雷
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ______________________________
#
#
#
# 缺點：
#
# 1.物理老師在哭泣
#
# 羅馬那場戲的炸彈，為何會著火還可以不爆炸，再把一堆東西碾爆？？？
#
# 爆炸後開車的速度可以躲避爆炸的衝擊波，也就是唐老大的車速大於爆炸波衝擊波？？？
#
#
# 去家裡抓唐老大兒子那場戲壞人可以被打到打壞家裡地板？？？危老建築？？？
#
# 從飛機上載一台小型噴射機，用幾瓶小小的烈酒當燃料，直接垂直往下沒有動力不會失速
# ？？？
#
# 最後父子葡萄牙衝下水庫物理慣性沒死？？？？？？
#
# 2.家族成員越來越多，分成多個團體，除了羅馬幾乎沒有集合。各說各的故事，等於有好
# 幾條故事線，很破碎。
#
# 唐老大自己一條線。
#
# 兒子跟叔叔姑姑還是阿姨我忘了一條線。
#
# 老婆一條線。
#
# 其他家族成員一條線。
#
# 再用一些功能角色跳來跳去說故事，有點讓我焦慮。
#
# 3.水行俠雖然演得好，但有點黑暗騎士小丑的Fu。
#
# 新的警察老大，很像巨石強森以前的角色，也是壯壯的，然後想要抓唐老大，最後突然想
# 要合作，超級硬XD ，只差在突然又轉黑。
#
# 人物設定有點老梗，是不是chatgpt 寫的？
#
# 4.結尾太唐突突然就結束了？？我覺得沒有結局。
#
# 水庫大爆炸，老大跟兒子在水裡生死未卜。
#
# 所有家族人生死未卜，反派也沒死或是被抓。
#
# 這是美劇某一集的結束的手法吧，電影至少要有個結局。
#
# 要不是吉賽兒跟巨石強森這兩個超人氣角色出現觀眾應該會翻臉吧？
#
# 5.最經典的飆車尬車戲，原本很期待。
#
# 水行俠、老大、雜魚男、正妹開始飆車。
#
# 然後水行俠說兩個你要救哪個，就要把唐老大以外的兩個人幹掉了，然後唐老大救了正妹
# ，男的就葛屁了？？男的該死？？
#
# 小吐槽至少蝙蝠俠黑暗騎士也有想辦法救兩邊。
#
# 但最重要的是我是知道壞人很壞啦但飆車呢？至少也跑一段最後再殺人吧。說好的飆車呢
# ？？？
#
#
#
#
#
# 優點：
#
# 1. 傑森 史塔森、韓哥、John Cena、吉賽爾、巨石強森回歸，包含回憶裡面的保羅沃克
# 回歸。誠意滿滿，但人物太多，所以每個人的戲份都不多。
#
# 2.水行俠演的很好，舔舔很棒。
#
# 3.動作戲流暢。
#
#
#
#
#
# 作者：abani (碘化鉀)
# 看板：movie
# 標題：[好雷] 玩命關頭X：驚喜客串
# 日期：Thu May 18 19:38:47 2023
# 內容：防雷防雷
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 看完了玩命關頭X覺得很棒！
#
# 上一集剪接節奏詭異的情況大幅改善，泰吉和羅曼嘴砲橋段太過冗長的缺點也不見了！
# （可能因為人物實在太多，出場秒數平均分一分嘴砲就剩下兩三句了哈哈哈哈）
#
# 搞笑方面個人覺得直逼玩命關頭8（個人覺得最好笑）的等級了！光是自婊無視物理定律
# 、烤烤肉就大家都變成family就100分！！
# 而劇本也很用心地幫忙大家複習角色哦！像小B看到雅各馬上叫叔叔、蜜雅對小B自稱姑姑
# 、兄妹碰面還不忘再提醒一次「我愛你，哥」「我也愛妳，妹」
#
# 深怕剛上車的觀眾看不懂有沒有XDD 超級用心XDD
#
#
# 劇本（充滿娛樂性的愚蠢度）和歡樂顛覆物理部分大家都提到很多了，在這邊分享兩個驚
# 喜客串的橋段：
#
#
# 第一位是Paul Walker的女兒Meadow Walker，似乎是客串遞酒給雅各的空服員？（如果看
# 錯請指正！）
#
# https://m.imdb.com/name/nm6239459/mediaviewer/rm1169105409/?ref_=ext_shr_lnk
# https://i.imgur.com/c1Nd1IE.jpg
# 這位
#
#
# 第二組是雅各和小B在機場背著不明長形行李差點撞到的旅客，是美國樂團Twenty One
# Pilots的鼓手Josh Dun和其妻子，演員Debby Ryan！！
#
# 看到這邊超喜歡Twenty One Pilots的我不小心尖叫出聲「WTF！」還被隔壁觀眾側目XDD
#
# https://people.com/tv/debby-ryan-josh-dun-relationship-timeline/
# https://i.imgur.com/roPhy97.jpg
# 是這對夫婦
#
#
# 以上！不知道版友還有沒有看到哪些意外的客串或驚喜呢？
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 頁末防雷防雷
